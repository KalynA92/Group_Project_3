# %%
## Analysis

# %%
# Import dependencies
from datetime import datetime
import pandas as pd

# %%
# Convert CSV to Pandas Dataframe 
data = pd.read_csv('./Resources/data.csv', index_col='Unnamed: 0')

# %%
# Check dataframe
data.head()
# Out:
#              timestamp  duration (seconds)        city state country  \
# 0  1949-10-10 20:30:00                2700  san marcos    tx      us
# 3  1956-10-10 21:00:00                  20        edna    tx      us
# 4  1960-10-10 20:00:00                 900     kaneohe    hi      us
# 5  1961-10-10 19:00:00                 300     bristol    tn      us
# 7  1965-10-10 23:45:00                1200     norwalk    ct      us
#
#     latitude   longitude     shape  \
# 0  29.883056  -97.941111  cylinder
# 3  28.978333  -96.645833    circle
# 4  21.418056 -157.803611     light
# 5  36.595000  -82.188889    sphere
# 7  41.117500  -73.408333      disk
#
#                                             comments
# 0  This event took place in early fall around 194...
# 3  My older brother and twin sister were leaving ...
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# 5  My father is now 89 my brother 52 the girl wit...
# 7  A bright orange color changing to reddish colo...

# %%
# Creating function for datetime column
def midnight(datetime):
    """Define a function to handle the houres that are 24."""
    date, time = datetime.split(" ")
    hour, minute = time.split(":")
    if hour == "24":
        hour = "00"
    result = date + " "+ hour +":"+ minute
    return result

# %%
# Coverting to datetime object
data["timestamp"] = pd.to_datetime(data["timestamp"])

# %%
# Cleaning dataframe
data = data[["timestamp", "city", "state", "country", "shape"]]

# %%
# Checking dataframe
data.head()
# Out:
#             timestamp        city state country     shape
# 0 1949-10-10 20:30:00  san marcos    tx      us  cylinder
# 3 1956-10-10 21:00:00        edna    tx      us    circle
# 4 1960-10-10 20:00:00     kaneohe    hi      us     light
# 5 1961-10-10 19:00:00     bristol    tn      us    sphere
# 7 1965-10-10 23:45:00     norwalk    ct      us      disk

# %%
# Finding the most frequent date for UFO sightings 
data['timestamp'].groupby(data['timestamp']).count().sort_values(ascending=False).head(10)
# Out:
# timestamp
# 2010-07-04 22:00:00    31
# 2012-07-04 22:00:00    29
# 1999-11-16 19:00:00    24
# 2010-07-04 21:00:00    23
# 2009-09-19 20:00:00    23
# 2011-07-04 22:00:00    22
# 2004-10-31 20:00:00    22
# 2013-07-04 22:00:00    20
# 2012-07-04 22:30:00    20
# 1999-11-16 19:05:00    19
# Name: timestamp, dtype: int64

# %%
# Finding the most frequent city for UFO sightings
data['city'].groupby(data['city']).count().sort_values(ascending=False).head(10)
# Out:
# city
# seattle        471
# phoenix        438
# las vegas      356
# portland       354
# los angeles    347
# san diego      328
# houston        292
# chicago        256
# tucson         237
# miami          230
# Name: city, dtype: int64

# %%
# Finding the most frequent shape for UFO sightings
data['shape'].groupby(data['shape']).count().sort_values(ascending=False).head(10)
# Out:
# shape
# light        14130
# triangle      6817
# circle        6405
# fireball      5364
# unknown       4774
# other         4705
# sphere        4552
# disk          4319
# oval          3160
# formation     2088
# Name: shape, dtype: int64

# %%
# Finding all the UFO sightings for the most frequent date
most_active_date = data[(data['timestamp'] == "7/4/2010 22:00")]
most_active_date
# Out:
#                 timestamp                           city state country  \
# 62151 2010-07-04 22:00:00  batesville (near lake santee)    in      us
# 62152 2010-07-04 22:00:00                     belleville    il      us
# 62153 2010-07-04 22:00:00                        bothell    wa      us
# 62156 2010-07-04 22:00:00                    cutlerville    mi      us
# 62157 2010-07-04 22:00:00                      deer park    oh      us
# 62158 2010-07-04 22:00:00                   fort calhoun    ne      us
# 62159 2010-07-04 22:00:00                    fort wright    ky      us
# 62160 2010-07-04 22:00:00                       gastonia    nc      us
# 62161 2010-07-04 22:00:00                     georgetown    ky      us
# 62162 2010-07-04 22:00:00                    heathsville    va      us
# 62163 2010-07-04 22:00:00                   indianapolis    in      us
# 62164 2010-07-04 22:00:00                       kingston    wa      us
# 62165 2010-07-04 22:00:00                   lake stevens    wa      us
# 62166 2010-07-04 22:00:00                       lakewood    wa      us
# 62167 2010-07-04 22:00:00                       lakewood    wa      us
# 62168 2010-07-04 22:00:00                         lamesa    tx      us
# 62169 2010-07-04 22:00:00                         lorain    oh      us
# 62170 2010-07-04 22:00:00                       lynnwood    wa      us
# 62171 2010-07-04 22:00:00                        milford    ne      us
# 62172 2010-07-04 22:00:00                       montrose    pa      us
# 62173 2010-07-04 22:00:00                     north bend    ne      us
# 62174 2010-07-04 22:00:00                         paxton    ma      us
# 62175 2010-07-04 22:00:00                    piney flats    tn      us
# 62176 2010-07-04 22:00:00                     portsmouth    oh      us
# 62177 2010-07-04 22:00:00                      rio linda    ca      us
# 62178 2010-07-04 22:00:00                          selma    ca      us
# 62180 2010-07-04 22:00:00                    springfield    ma      us
# 62181 2010-07-04 22:00:00                          tampa    fl      us
# 62182 2010-07-04 22:00:00                      vancouver    wa      us
# 62183 2010-07-04 22:00:00                      vancouver    wa      us
# 62185 2010-07-04 22:00:00                      waterbury    ct      us
#
#            shape
# 62151   fireball
# 62152     circle
# 62153     sphere
# 62156     sphere
# 62157   changing
# 62158     circle
# 62159   fireball
# 62160   fireball
# 62161   fireball
# 62162   fireball
# 62163   fireball
# 62164      light
# 62165     circle
# 62166   cylinder
# 62167   fireball
# 62168     circle
# 62169     circle
# 62170     circle
# 62171   fireball
# 62172   fireball
# 62173    unknown
# 62174    unknown
# 62175      other
# 62176      light
# 62177   fireball
# 62178      other
# 62180      light
# 62181    unknown
# 62182   fireball
# 62183  formation
# 62185   triangle

# %%
# Diplaying 'city' and 'shape' column for plotting
columns = ['city', 'shape']
city_shape_date = pd.DataFrame(most_active_date, columns=columns)
city_shape_date
# Out:
#                                 city      shape
# 62151  batesville (near lake santee)   fireball
# 62152                     belleville     circle
# 62153                        bothell     sphere
# 62156                    cutlerville     sphere
# 62157                      deer park   changing
# 62158                   fort calhoun     circle
# 62159                    fort wright   fireball
# 62160                       gastonia   fireball
# 62161                     georgetown   fireball
# 62162                    heathsville   fireball
# 62163                   indianapolis   fireball
# 62164                       kingston      light
# 62165                   lake stevens     circle
# 62166                       lakewood   cylinder
# 62167                       lakewood   fireball
# 62168                         lamesa     circle
# 62169                         lorain     circle
# 62170                       lynnwood     circle
# 62171                        milford   fireball
# 62172                       montrose   fireball
# 62173                     north bend    unknown
# 62174                         paxton    unknown
# 62175                    piney flats      other
# 62176                     portsmouth      light
# 62177                      rio linda   fireball
# 62178                          selma      other
# 62180                    springfield      light
# 62181                          tampa    unknown
# 62182                      vancouver   fireball
# 62183                      vancouver  formation
# 62185                      waterbury   triangle

# %%
# Write data to file in json format
city_shape_data = city_shape_date.to_json(orient="records")
with open("./Resources/cityshape.js", "w") as outfile:
    outfile.write(city_shape_data)

# %%
# Finding the earliest date for a UFO sighting
data['timestamp'].min()
# Out:
# Timestamp('1910-01-01 00:00:00')

# %%
# Finding the most recent date for a UFO sighting
data['timestamp'].max()
# Out:
# Timestamp('2014-05-08 00:00:00')

# %%
# Finding all the UFO sightings for the first 40 years sorted by date
first_40_year = data[(data['timestamp'] > '1910-01-01') & (data['timestamp'] <= '1940-12-31')] 
first_40_year.sort_values(by=['timestamp'], inplace = True)
first_40_year
# Out:
# C:\Users\Kalyn\AppData\Local\Temp\ipykernel_49068\3598493454.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   first_40_year.sort_values(by=['timestamp'], inplace = True)
#                 timestamp                              city state country  \
# 46858 1910-06-01 15:00:00                       wills point    tx      us
# 46694 1920-06-11 21:00:00                            cicero    in      us
# 20951 1925-12-28 18:00:00       atkinson (6 miles north of)    il      us
# 62760 1929-07-05 14:00:00              buchanan  (or burns)    or      us
# 26550 1931-02-15 14:00:00  holyoke (6-8 miles southwest of)    co      us
# 46860 1931-06-01 13:00:00                           abilene    ks      us
# 74514 1934-09-15 15:30:00   valley city (6.5 miles east of)    nd      us
# 74515 1936-09-15 19:00:00                   albany (canada)    pe      ca
# 1704  1936-10-15 17:00:00                           eklutna    ak      us
# 48568 1937-06-15 00:00:00                           hubbard    or      us
# 66131 1937-08-15 21:00:00                           fontana    ca      us
# 46861 1939-06-01 20:00:00                          waterloo    al      us
# 52588 1939-06-30 20:00:00                            belton    sc      us
# 63340 1939-07-07 02:00:00                            keokuk    ia      us
#
#            shape
# 46858      cigar
# 46694    unknown
# 20951       disk
# 62760       disk
# 26550       oval
# 46860       disk
# 74514       disk
# 74515  rectangle
# 1704       cigar
# 48568   cylinder
# 66131      light
# 46861   fireball
# 52588     sphere
# 63340       oval

# %%
# Finding the variety of shapes of UFO sightings seen in the first 40 years
shapes1 = first_40_year['shape'].groupby(first_40_year['shape']).count().sort_values(ascending=False).head(7)
shapes1
# Out:
# shape
# disk         4
# cigar        2
# oval         2
# cylinder     1
# fireball     1
# light        1
# rectangle    1
# Name: shape, dtype: int64

# %%
# Create Dataframe for plotting
shapes1_df = pd.DataFrame(shapes1, columns=['shape'])
shapes1_df = shapes1_df.rename_axis('count')
shapes1_df = shapes1_df.reset_index()
shapes1_df.rename(columns={'count':'Shape', 'shape': 'Total Count'}, inplace=True)
shapes1_df
# Out:
#        Shape  Total Count
# 0       disk            4
# 1      cigar            2
# 2       oval            2
# 3   cylinder            1
# 4   fireball            1
# 5      light            1
# 6  rectangle            1

# %%
# Write data to file in json format
first_years_shape = shapes1_df.to_json(orient="records")
with open("./Resources/firstyearsshape.js", "w") as outfile:
    outfile.write(first_years_shape)

# %%
# Finding all the UFO sightings for the first year TV's were most common in American homes sorted by date
tv = data[(data['timestamp'] > '1955-01-01') & (data['timestamp'] <= '1955-12-31')]
tv.sort_values(by=['timestamp'], inplace = True)
tv
# Out:
# C:\Users\Kalyn\AppData\Local\Temp\ipykernel_49068\1193259381.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv.sort_values(by=['timestamp'], inplace = True)
#                 timestamp                                        city state  \
# 26553 1955-02-15 19:00:00                    new york city (brooklyn)    ny
# 41490 1955-05-01 15:00:00                                    holbrook    ma
# 42291 1955-05-15 03:00:00                                  warrington    fl
# 46893 1955-06-01 02:00:00                                      bagley    mn
# 46894 1955-06-01 15:29:00                                  cincinnati    oh
# 46895 1955-06-01 17:00:00                        martinez (outskirts)    ca
# 46896 1955-06-01 20:30:00                                     clinton    tn
# 53768 1955-06-06 01:00:00                                   pensacola    fl
# 48589 1955-06-15 21:00:00                               daytona beach    fl
# 49658 1955-06-17 07:00:00                                     rantoul    il
# 51166 1955-06-23 07:00:00                            beach haven park    nj
# 52610 1955-06-30 00:00:00                                 quartz hill    ca
# 52611 1955-06-30 13:00:00                                     lubbock    tx
# 52612 1955-06-30 21:00:00                                       dumas    tx
# 52613 1955-06-30 21:00:00                               morehead city    nc
# 55118 1955-07-01 14:00:00  carnation (on tolt river&#44 cascade mts.)    wa
# 55119 1955-07-01 22:00:00                                      dierks    ar
# 56464 1955-07-15 14:00:00                               woodland park    co
# 71767 1955-08-06 19:00:00                              newtown square    pa
# 72267 1955-08-08 01:00:00                                independence    mo
# 66147 1955-08-15 00:01:00                                  eagle pass    tx
# 67108 1955-08-17 21:00:00                                      covina    ca
# 6020  1955-10-03 06:00:00                     stanley (near) (canada)    nb
# 1713  1955-10-15 20:00:00                                   rhinebeck    ny
#
#       country     shape
# 26553      us     light
# 41490      us       egg
# 42291      us  fireball
# 46893      us    circle
# 46894      us      disk
# 46895      us    circle
# 46896      us       egg
# 53768      us     light
# 48589      us  fireball
# 49658      us     light
# 51166      us      disk
# 52610      us      disk
# 52611      us     cigar
# 52612      us     light
# 52613      us      disk
# 55118      us      disk
# 55119      us     cigar
# 56464      us      oval
# 71767      us    circle
# 72267      us  fireball
# 66147      us     cigar
# 67108      us      disk
# 6020       ca      disk
# 1713       us     light

# %%
# Finding the variety of shapes of UFO sightings seen in the first year TV's were most common in American homes
shapes2 = tv['shape'].groupby(tv['shape']).count().sort_values(ascending=False).head(7)
shapes2
# Out:
# shape
# disk        7
# light       5
# cigar       3
# circle      3
# fireball    3
# egg         2
# oval        1
# Name: shape, dtype: int64

# %%
# Create Dataframe for plotting
shapes2_df = pd.DataFrame(shapes2, columns=['shape'])
shapes2_df = shapes2_df.rename_axis('count')
shapes2_df = shapes2_df.reset_index()
shapes2_df.rename(columns={'count':'Shape', 'shape': 'Total Count'}, inplace=True)
shapes2_df
# Out:
#       Shape  Total Count
# 0      disk            7
# 1     light            5
# 2     cigar            3
# 3    circle            3
# 4  fireball            3
# 5       egg            2
# 6      oval            1

# %%
# Write data to file in json format
tv_data = shapes2_df.to_json(orient="records")
with open("./Resources/tvdata.js", "w") as outfile:
    outfile.write(tv_data)

# %%
# Finding all the UFO sightings for the first year after Apollo 13 sorted by date
moon_landing = data[(data['timestamp'] > '1969-07-16') & (data['timestamp'] <= '1970-07-16')]
moon_landing.sort_values(by=['timestamp'], inplace = True)
moon_landing
# Out:
# C:\Users\Kalyn\AppData\Local\Temp\ipykernel_49068\2272608523.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   moon_landing.sort_values(by=['timestamp'], inplace = True)
#                 timestamp            city state country    shape
# 60041 1969-07-27 21:45:00     rocky mount    nc      us   sphere
# 60727 1969-07-30 13:00:00           akron    oh      us   circle
# 60970 1969-07-31 20:00:00     summerville    sc      us    light
# 64794 1969-08-01 17:30:00          dayton    oh      us     disk
# 64796 1969-08-01 21:00:00      new castle    pa      us     oval
# ...                   ...             ...   ...     ...      ...
# 56554 1970-07-15 19:00:00   south windsor    ct      us     oval
# 56555 1970-07-15 20:00:00  indian orchard    ma      us  unknown
# 56556 1970-07-15 21:30:00            tyre    ny      us    other
# 56558 1970-07-15 22:00:00       roseville    ca      us     disk
# 56559 1970-07-15 23:30:00      pittsfield    ma      us    light
#
# [120 rows x 5 columns]

# %%
# Finding the variety of shapes of UFO sightings seen in the first year after Apollo 13
shapes3 = moon_landing['shape'].groupby(moon_landing['shape']).count().sort_values(ascending=False).head(12)
shapes3
# Out:
# shape
# disk         31
# circle       14
# light        13
# oval         13
# other        10
# cigar         9
# sphere        8
# unknown       6
# cylinder      5
# formation     4
# changing      2
# egg           2
# Name: shape, dtype: int64

# %%
# Create Dataframe for plotting
shapes3_df = pd.DataFrame(shapes3, columns=['shape'])
shapes3_df = shapes3_df.rename_axis('count')
shapes3_df = shapes3_df.reset_index()
shapes3_df.rename(columns={'count':'Shape', 'shape': 'Total Count'}, inplace=True)
shapes3_df
# Out:
#         Shape  Total Count
# 0        disk           31
# 1      circle           14
# 2       light           13
# 3        oval           13
# 4       other           10
# 5       cigar            9
# 6      sphere            8
# 7     unknown            6
# 8    cylinder            5
# 9   formation            4
# 10   changing            2
# 11        egg            2

# %%
# Write data to file in json format
apollo_13 = shapes3_df.to_json(orient="records")
with open("./Resources/apollo13.js", "w") as outfile:
    outfile.write(apollo_13)

# %%
# Finding all the UFO sightings for the first year after the first Star Wars movie was released sorted by date
a_new_hope = data[(data['timestamp'] > '1977-05-25') & (data['timestamp'] <= '1978-05-25')]
a_new_hope.sort_values(by=['timestamp'], inplace = True)
a_new_hope
# Out:
# C:\Users\Kalyn\AppData\Local\Temp\ipykernel_49068\256554822.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a_new_hope.sort_values(by=['timestamp'], inplace = True)
#                 timestamp                                  city state country  \
# 44217 1977-05-25 01:00:00                              marshall    il      us
# 44682 1977-05-28 00:00:00                              meridian    id      us
# 44683 1977-05-28 00:01:00                              meridian    id      us
# 44684 1977-05-28 21:00:00                           los angeles    ca      us
# 44844 1977-05-29 23:30:00                             watertown    ny      us
# ...                   ...                                   ...   ...     ...
# 45841 1978-05-06 21:00:00                            barrington    il      us
# 46006 1978-05-07 21:50:00                         grand prairie    tx      us
# 41151 1978-05-10 20:30:00                             san diego    ca      us
# 41152 1978-05-10 20:30:00                              sandwich    ma      us
# 44080 1978-05-24 01:30:00  paramus (route 4&#44 eastbound lane)    nj      us
#
#           shape
# 44217     cigar
# 44682      disk
# 44683      disk
# 44684     cigar
# 44844     cigar
# ...         ...
# 45841  triangle
# 46006  triangle
# 41151  changing
# 41152  triangle
# 44080     cigar
#
# [217 rows x 5 columns]

# %%
# Finding the variety of shapes of UFO sightings seen in the first year after the first Star Wars movie was released
shapes4 = a_new_hope['shape'].groupby(a_new_hope['shape']).count().sort_values(ascending=False).head(20)
shapes4
# Out:
# shape
# disk         46
# triangle     34
# light        21
# circle       19
# cigar        15
# oval         15
# sphere       14
# other        14
# unknown      10
# chevron       6
# changing      4
# diamond       3
# rectangle     3
# cylinder      3
# fireball      3
# formation     2
# flash         2
# egg           2
# cone          1
# Name: shape, dtype: int64

# %%
# Create Dataframe for plotting
shapes4_df = pd.DataFrame(shapes4, columns=['shape'])
shapes4_df = shapes4_df.rename_axis('count')
shapes4_df = shapes4_df.reset_index()
shapes4_df.rename(columns={'count':'Shape', 'shape': 'Total Count'}, inplace=True)
shapes4_df
# Out:
#         Shape  Total Count
# 0        disk           46
# 1    triangle           34
# 2       light           21
# 3      circle           19
# 4       cigar           15
# 5        oval           15
# 6      sphere           14
# 7       other           14
# 8     unknown           10
# 9     chevron            6
# 10   changing            4
# 11    diamond            3
# 12  rectangle            3
# 13   cylinder            3
# 14   fireball            3
# 15  formation            2
# 16      flash            2
# 17        egg            2
# 18       cone            1

# %%
# Write data to file in json format
new_hope = shapes4_df.to_json(orient="records")
with open("./Resources/newhope.js", "w") as outfile:
    outfile.write(new_hope)

# %%
# Finding the variety of shapes seen in the first year after the first private manned space vehicle flew into space sorted by date.
private_ship = data[(data['timestamp'] > '2004-06-21') & (data['timestamp'] <= '2005-06-21')]
private_ship.sort_values(by=['timestamp'], inplace = True)
private_ship
# Out:
# C:\Users\Kalyn\AppData\Local\Temp\ipykernel_49068\3494035974.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   private_ship.sort_values(by=['timestamp'], inplace = True)
#                 timestamp                city state country      shape
# 50639 2004-06-21 09:30:00       richmond hill    ny      us       disk
# 50640 2004-06-21 16:12:00              newark    oh      us    unknown
# 50641 2004-06-21 20:00:00             buckeye    az      us      light
# 50642 2004-06-21 21:58:00                ames    ia      us    unknown
# 50644 2004-06-21 23:15:00  ladysmith (canada)    bc      ca    unknown
# ...                   ...                 ...   ...     ...        ...
# 50416 2005-06-20 21:30:00          frostproof    fl      us   fireball
# 50417 2005-06-20 21:45:00       san francisco    ca      us  formation
# 50418 2005-06-20 21:50:00         gulf shores    al      us      light
# 50419 2005-06-20 23:22:00       potomac falls    va      us   triangle
# 50646 2005-06-21 00:00:00           vancouver    wa      us     circle
#
# [3310 rows x 5 columns]

# %%
# Finding the variety of shapes of UFO sightings seen in the first year after the first private manned space vehicle flew into space
shapes5 = private_ship['shape'].groupby(private_ship['shape']).count().sort_values(ascending=False).head(21)
shapes5
# Out:
# shape
# light        762
# triangle     410
# circle       276
# unknown      273
# other        251
# sphere       203
# disk         200
# fireball     157
# oval         139
# formation    116
# changing     104
# cigar         76
# flash         66
# rectangle     51
# chevron       49
# diamond       46
# cylinder      45
# teardrop      35
# egg           29
# cone          12
# cross         10
# Name: shape, dtype: int64

# %%
# Create Dataframe for plotting
shapes5_df = pd.DataFrame(shapes5, columns=['shape'])
shapes5_df = shapes5_df.rename_axis('count')
shapes5_df = shapes5_df.reset_index()
shapes5_df.rename(columns={'count':'Shape', 'shape': 'Total Count'}, inplace=True)
shapes5_df
# Out:
#         Shape  Total Count
# 0       light          762
# 1    triangle          410
# 2      circle          276
# 3     unknown          273
# 4       other          251
# 5      sphere          203
# 6        disk          200
# 7    fireball          157
# 8        oval          139
# 9   formation          116
# 10   changing          104
# 11      cigar           76
# 12      flash           66
# 13  rectangle           51
# 14    chevron           49
# 15    diamond           46
# 16   cylinder           45
# 17   teardrop           35
# 18        egg           29
# 19       cone           12
# 20      cross           10

# %%
# Write data to file in json format
privateship = shapes5_df.to_json(orient="records")
with open("./Resources/privateship.js", "w") as outfile:
    outfile.write(privateship)

# %%
# Finding all the UFO sightings for the last year sorted by date
last_year = data[(data['timestamp'] > '2013-05-08') & (data['timestamp'] <= '2014-05-08')] 
last_year.sort_values(by=['timestamp'], inplace = True)
last_year
# Out:
# C:\Users\Kalyn\AppData\Local\Temp\ipykernel_49068\1895797853.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_year.sort_values(by=['timestamp'], inplace = True)
#                 timestamp               city state country      shape
# 46288 2013-05-08 01:00:00  winnipeg (canada)    mb      ca     circle
# 46289 2013-05-08 13:30:00            boulder    co      us        egg
# 46290 2013-05-08 20:00:00         scottsdale    az      us    unknown
# 46291 2013-05-08 20:50:00        lake placid    fl      us      light
# 46292 2013-05-08 21:47:00             onaway    mi      us   triangle
# ...                   ...                ...   ...     ...        ...
# 46151 2014-05-07 20:30:00            visalia    ca      us   fireball
# 46152 2014-05-07 21:00:00           theodore    al      us     circle
# 46153 2014-05-07 21:10:00          naugatuck    ct      us    unknown
# 46154 2014-05-07 21:20:00          hillsboro    mo      us   fireball
# 46301 2014-05-08 00:00:00            memphis    tn      us  rectangle
#
# [6908 rows x 5 columns]

# %%
# Finding the variety of shapes of UFO sightings seen in the last year of the data
last_shapes = last_year['shape'].groupby(last_year['shape']).count().sort_values(ascending=False).head(21)
last_shapes
# Out:
# shape
# light        1522
# fireball      901
# circle        899
# sphere        577
# triangle      552
# unknown       445
# other         365
# oval          271
# formation     266
# disk          209
# changing      146
# flash         141
# cylinder      111
# cigar         108
# diamond        98
# rectangle      92
# chevron        58
# egg            49
# teardrop       45
# cross          27
# cone           26
# Name: shape, dtype: int64

# %%
# Create Dataframe for plotting
last_shapes_df = pd.DataFrame(last_shapes, columns=['shape'])
last_shapes_df = last_shapes_df.rename_axis('count')
last_shapes_df = last_shapes_df.reset_index()
last_shapes_df.rename(columns={'count':'Shape', 'shape': 'Total Count'}, inplace=True)
last_shapes_df
# Out:
#         Shape  Total Count
# 0       light         1522
# 1    fireball          901
# 2      circle          899
# 3      sphere          577
# 4    triangle          552
# 5     unknown          445
# 6       other          365
# 7        oval          271
# 8   formation          266
# 9        disk          209
# 10   changing          146
# 11      flash          141
# 12   cylinder          111
# 13      cigar          108
# 14    diamond           98
# 15  rectangle           92
# 16    chevron           58
# 17        egg           49
# 18   teardrop           45
# 19      cross           27
# 20       cone           26

# %%
# Write data to file in json format
final_year = last_shapes_df.to_json(orient="records")
with open("./Resources/finalyear.js", "w") as outfile:
    outfile.write(final_year)

# %%
# Finding the count of every UFO sighting per year
data['Year'] = data['timestamp'].apply(lambda x: "%d" % (x.year))
result = data.groupby(['Year']).size()
result
# Out:
# Year
# 1910       2
# 1920       1
# 1925       1
# 1929       1
# 1931       2
#         ...
# 2010    3645
# 2011    4456
# 2012    6489
# 2013    6237
# 2014    1973
# Length: 83, dtype: int64

# %%
# Create Dataframe for plotting
sighting_per_year = pd.DataFrame(result)
sighting_per_year = sighting_per_year.reset_index()
sighting_per_year
# Out:
#     Year     0
# 0   1910     2
# 1   1920     1
# 2   1925     1
# 3   1929     1
# 4   1931     2
# ..   ...   ...
# 78  2010  3645
# 79  2011  4456
# 80  2012  6489
# 81  2013  6237
# 82  2014  1973
#
# [83 rows x 2 columns]

# %%
# Write data to file in json format
yearly_sightings = sighting_per_year.to_json(orient="records")
with open("./Resources/yearlysightings.js", "w") as outfile:
    outfile.write(yearly_sightings)
