# %%
## Sree Analysis - DB and Flask APIs

# %%
# Import dependencies
from datetime import datetime
import pandas as pd

# %%
# Convert CSV to Pandas Dataframe 
data = pd.read_csv('./Resources/data.csv', index_col='Unnamed: 0')

# %%
# Check dataframe
data.head()
# Out:
#              timestamp  duration (seconds)        city state country  \
# 0  1949-10-10 20:30:00                2700  san marcos    tx      us
# 3  1956-10-10 21:00:00                  20        edna    tx      us
# 4  1960-10-10 20:00:00                 900     kaneohe    hi      us
# 5  1961-10-10 19:00:00                 300     bristol    tn      us
# 7  1965-10-10 23:45:00                1200     norwalk    ct      us
#
#     latitude   longitude     shape  \
# 0  29.883056  -97.941111  cylinder
# 3  28.978333  -96.645833    circle
# 4  21.418056 -157.803611     light
# 5  36.595000  -82.188889    sphere
# 7  41.117500  -73.408333      disk
#
#                                             comments
# 0  This event took place in early fall around 194...
# 3  My older brother and twin sister were leaving ...
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# 5  My father is now 89 my brother 52 the girl wit...
# 7  A bright orange color changing to reddish colo...

# %%
# Creating function for datetime column
def midnight(datetime):
    """Define a function to handle the houres that are 24."""
    date, time = datetime.split(" ")
    hour, minute = time.split(":")
    if hour == "24":
        hour = "00"
    result = date + " "+ hour +":"+ minute
    return result

# %%
# Coverting to datetime object
data["timestamp"] = pd.to_datetime(data["timestamp"])

# %%
data.head()
# Out:
#             timestamp  duration (seconds)        city state country  \
# 0 1949-10-10 20:30:00                2700  san marcos    tx      us
# 3 1956-10-10 21:00:00                  20        edna    tx      us
# 4 1960-10-10 20:00:00                 900     kaneohe    hi      us
# 5 1961-10-10 19:00:00                 300     bristol    tn      us
# 7 1965-10-10 23:45:00                1200     norwalk    ct      us
#
#     latitude   longitude     shape  \
# 0  29.883056  -97.941111  cylinder
# 3  28.978333  -96.645833    circle
# 4  21.418056 -157.803611     light
# 5  36.595000  -82.188889    sphere
# 7  41.117500  -73.408333      disk
#
#                                             comments
# 0  This event took place in early fall around 194...
# 3  My older brother and twin sister were leaving ...
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# 5  My father is now 89 my brother 52 the girl wit...
# 7  A bright orange color changing to reddish colo...

# %%
data.insert(0, 'ID', range(1000, 1000 + len(data)))

# %%
data.head()
# Out:
#      ID           timestamp  duration (seconds)        city state country  \
# 0  1000 1949-10-10 20:30:00                2700  san marcos    tx      us
# 3  1001 1956-10-10 21:00:00                  20        edna    tx      us
# 4  1002 1960-10-10 20:00:00                 900     kaneohe    hi      us
# 5  1003 1961-10-10 19:00:00                 300     bristol    tn      us
# 7  1004 1965-10-10 23:45:00                1200     norwalk    ct      us
#
#     latitude   longitude     shape  \
# 0  29.883056  -97.941111  cylinder
# 3  28.978333  -96.645833    circle
# 4  21.418056 -157.803611     light
# 5  36.595000  -82.188889    sphere
# 7  41.117500  -73.408333      disk
#
#                                             comments
# 0  This event took place in early fall around 194...
# 3  My older brother and twin sister were leaving ...
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# 5  My father is now 89 my brother 52 the girl wit...
# ...

# %%
ordered_df = data[['ID','shape','city','latitude','longitude','state','country','duration (seconds)','timestamp','comments']]

# %%
ordered_df.head()
# Out:
#      ID     shape        city   latitude   longitude state country  \
# 0  1000  cylinder  san marcos  29.883056  -97.941111    tx      us
# 3  1001    circle        edna  28.978333  -96.645833    tx      us
# 4  1002     light     kaneohe  21.418056 -157.803611    hi      us
# 5  1003    sphere     bristol  36.595000  -82.188889    tn      us
# 7  1004      disk     norwalk  41.117500  -73.408333    ct      us
#
#    duration (seconds)           timestamp  \
# 0                2700 1949-10-10 20:30:00
# 3                  20 1956-10-10 21:00:00
# 4                 900 1960-10-10 20:00:00
# 5                 300 1961-10-10 19:00:00
# 7                1200 1965-10-10 23:45:00
#
#                                             comments
# 0  This event took place in early fall around 194...
# 3  My older brother and twin sister were leaving ...
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# 5  My father is now 89 my brother 52 the girl wit...
# ...

# %%
ordered_df.rename(columns={"duration(seconds)": "duration_seconds"}, inplace=True)

# %%
ordered_df.to_csv("Resources/orderedData.csv", index=False, header=True, encoding='UTF-8')
